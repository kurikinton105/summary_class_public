# %%
import azure.cognitiveservices.speech as speechsdk
import time
from password import * #passwordのインポート


def speech2text(audio_filename,out_filename):
    def stop_cb(evt):
        if evt.result.reason == speechsdk.ResultReason.RecognizedSpeech:
            print('CLOSING on {}'.format(evt))
        speech_recognizer.stop_continuous_recognition()
        nonlocal done
        done = True


    def recognized_cb(evt):
        print(evt.result.text)
        out.write(evt.result.text+'\n')
        
    done = False
    out = open("out_filename",'w')
    
    #speech_key, service_region = "xxxxx", "xxxxx"
    
    speech_config = speechsdk.SpeechConfig(subscription=speech_key, region=service_region)
    speech_config.enable_dictation()
    audio_input = speechsdk.audio.AudioConfig(filename=audio_filename)
    source_language_config = speechsdk.languageconfig.SourceLanguageConfig("ja-JP")
    
    speech_recognizer = speechsdk.SpeechRecognizer(speech_config=speech_config, source_language_config=source_language_config,audio_config=audio_input)
    #speech_recognizer.recognizing.connect(lambda evt: print('RECOGNIZING: {}'.format(evt)))
    #speech_recognizer.recognized.connect(lambda evt: print('RECOGNIZED: {}'.format(evt)))
    speech_recognizer.recognized.connect(recognized_cb)
    #speech_recognizer.session_started.connect(lambda evt: print('SESSION STARTED: {}'.format(evt)))
    #speech_recognizer.session_stopped.connect(lambda evt: print('SESSION STOPPED {}'.format(evt)))
    #speech_recognizer.canceled.connect(lambda evt: print('CANCELED {}'.format(evt)))

    speech_recognizer.session_stopped.connect(stop_cb)
    speech_recognizer.canceled.connect(stop_cb)
    
    speech_recognizer.start_continuous_recognition()
    while not done:
        time.sleep(.5)
    out.close()
    print("Done\n")

# %%
name =""
speech2text(name+".wav",name+".txt")
# Out:
# Awk。
# Awk。
# Okayama質問が一見すればいいんですね。はいえーと質問。ベクトル化した後に五歳にして見られて求める方法がわからないですっていうのが質問ですけど。湖西市メルティーを求める方法ですけど、それぞれベクトルのなす角を求めればよいというものですネット。
# 今これえーっと。
# 問題のところ別の所。
# いいん？
# 皆さん、手元に強化されますよね。ちょっと寒い。きっと毎日があるんだと思うようにしています。Byh。
# 先生はpcの話が書いていない。
# コメントをつけると、今ここに少ないtがs一とs2で書いてますけど、ペットコサイン？
# つらい近すぎだね。ちょっとサインのヘッドエスワンと。
# いいですね。
# はいしませんかネット？
# いっしょ。
# あ。
# 今xx。
# ベクトル。
# どうしましょう？えっ？とs2のベクトルがエックス版で英数。
# のベクトルx1でs2のベクトルx2とすると、こんな遺跡を使って計算できまして、どこ？
# ええ、それぞれエックスノ。
# 学んださ。
# と。
# エックス2-4の。
# の。
# 何だった？
# お腹ですか？はい、えー。こんな感じで求めることができますって。えっ？と、まあ、ここ、今、それぞれ大好きで書いてますけど、ヘッド二期って考えてもいいの？コピーと聞いて頂けると、x1の方のaベクトルをx1の長さで正規化してエックスノ4-6ドルをミックスの中で生活しては長さ一になるベクトルだと思って、その二つの間の資格と言うので、求めていることにも相当します。
# 内積の方はこれ今なんか両方とも一握頻度ベクトルじゃなくて場合なるべくの場合ですけど、ダイナブックの場合にはあまりなじみすればいいのか？計算は簡単で、このところ順番にかけて行けばよい。いろんなところが零になっていますのでのところはえないから上のコラボになってきたのところはこのところ、いちにさんしっ五六ですか？あるルートのロックかける六a分母が六で、分子の方はこの。
# お互いになっている事件だけを出したもので、ごので5/6っていうのがこちらのええvibramの時のサイズの計算になります。
# 他にも質問があったら、ちょっとできなければ個別にいただければ全体に帰属します。
# Okeyし。
# ...

# %%
import os
import glob
filepath = './komachi_audio/*'
files = glob.glob(filepath)
for file in files:
    print(file)
    name =file
    
    
speech2text("komachi_audio/7_6__5.wav","komachi7_6_3.txt")
# Out:
# ./komachi_audio/7_6__5.wav
# ./komachi_audio/7_6__4.wav
# ./komachi_audio/6_16.mp3
# ./komachi_audio/7_6__3.wav
# ./komachi_audio/7_6___2.wav
# これはいいのかあれ、図がない。
# 図がない、やっぱりですね。はい。今のようなえっと活性化関数変えた状態でどういう風な分離平面できるかって言うと同じように、このデータは全く同じですけど、最終的に学習が終わったときの線はこんな所ピットひいています。まあ、さっきと比べてまあいいか悪いかですけど、まあ、こんな感じの姓さっきと見比べましょうか。先ほどはこんな感じで、パーセプトロンの悪い単純パーセプトロンよくないところは分類に正解するともうそこで更新を止めるんですね。なので、このキワキワのとこですね。ここで言うとこの資格ですが、資格の義理。
# 義理のところでなんかも諦めちゃって、もう止めてるんですね。なので、本当はこのあたりでもデータがあったりしたら本当はえっと、こういう風に線を引いて欲しかったのに聞けないということがあります。なんでまあ、こっちノアダプティブ二百司会の方がちょっとちょっとマシですね。本当はこのあたりデータがない。よくわからないんですけど、ちょっとマシになっていると。
# Done
